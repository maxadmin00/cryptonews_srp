# %%
from selenium import webdriver
from datetime import timedelta, datetime
from bs4 import BeautifulSoup
import pandas as pd
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.common.action_chains import ActionChains

# %%
driver = webdriver.Chrome()
driver.get('https://www.cointelegraph.com/tags/nft')
#html = driver.page_source
#soup = BeautifulSoup(html)
data = []

SCROLL_PAUSE_TIME = 5

# Get scroll height
last_height = 0
html = None
sleep_time = 1

while True:
    html = driver.page_source
    soup = BeautifulSoup(html)
    content = soup.find_all("div",attrs={"class":"post-card-inline__header"})
    time_data = soup.find_all("div",attrs={"class":"post-card-inline__meta"}) 

    print(len(content))
    try:
        button = driver.find_elements(By.XPATH, '//*[@id="__layout"]/div/div[3]/div[4]/main/div/div/div[1]/div[3]/div/div/a')[0]
        bottom = driver.find_elements(By.XPATH, '//*[@id="__layout"]/div/div[3]/div[4]/main/div/div/div[1]/div[3]/div/div')[0]
        action = ActionChains(driver) 
        action.move_to_element(bottom).perform()
    except:
        bottom = driver.find_elements(By.CLASS_NAME, "post-card-inline__title")[-1]
        action = ActionChains(driver) 
        action.move_to_element(bottom).perform()
    #action = ActionChains(driver) 
    #action.move_to_element(button).click().perform()
    #driver.execute_script(f"window.scrollTo(0, {button.location['y']});")
    #button.click()
    try:
        button.click()
        time.sleep(sleep_time)
    except:
        time.sleep(sleep_time)
# Out:
# 15
# 30
# 45
# 60
# 75
# 90
# 105
# 120
# 135
# 150
# 165
# 180
# 195
# 210
# 225
# 240
# 255
# 270
# 285
# 300
# 315
# 330
# 345
# 360
# 375
# 390
# 405
# 420
# 435
# 450
# 465
# 480
# 495
# 510
# 525
# 540
# 555
# 570
# 585
# 600
# 615
# 630
# 645
# 660
# 675
# 690
# 705
# 720
# 735
# 750
# 765
# 780
# 795
# 810
# 825
# 840
# 855
# 870
# 885
# 900
# 915
# 930
# 945
# 960
# 975
# 990
# 1005
# 1020
# 1035
# 1050
# 1065
# 1080
# 1095
# 1110
# 1125
# 1140
# 1155
# 1170
# 1185
# 1200
# 1215
# 1230
# 1245
# 1260
# 1275
# 1290
# 1305
# 1320
# 1335
# 1350
# 1365
# 1380
# 1395
# 1410
# 1425
# 1440
# 1455
# 1470
# 1485
# 1500
# 1515
# 1530
# 1545
# 1560
# 1575
# 1590
# 1605
# 1620
# 1635
# 1650
# 1665
# 1680
# 1695
# 1710
# 1725
# 1740
# 1755
# 1770
# 1785
# 1800
# 1815
# 1830
# 1845
# 1860
# 1875
# 1890
# 1905
# 1920
# 1935
# 1950
# 1965
# 1980
# 1995
# 2010
# 2025
# 2040
# 2055
# 2070
# 2085
# 2100
# 2115
# 2130
# 2145
# 2160
# 2175
# 2190
# 2205
# 2220
# 2235
# 2250
# 2265
# 2280
# 2295
# 2310
# 2325
# 2340
# 2355
# 2370
# 2385
# 2400
# 2415
# 2430
# 2445
# 2460
# 2475
# 2490
# 2505
# 2520
# 2535
# 2550
# 2565
# 2580
# 2595
# 2610
# 2625
# 2640
# 2655
# 2670
# 2685
# 2700
# 2715
# 2730
# 2745
# 2760
# 2775
# 2790
# 2805
# 2820
# 2835
# 2850
# 2865
# 2880
# 2895
# 2910
# 2925
# 2940
# 2955
# 2970
# 2985
# 3000
# 3015
# 3030
# 3045
# 3060
# 3075
# 3090
# 3105
# 3120
# 3135
# 3150
# 3165
# 3180
# 3195
# 3210
# 3225
# 3240
# 3255
# 3270
# 3285
# 3300
# 3315
# 3330
# 3345
# 3360
# 3375
# 3390
# 3405
# 3420
# 3435
# 3450
# 3465
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# 3474
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# Cell In[2], line 22
#      21 try:
# ---> 22     button = driver.find_elements(By.XPATH, '//*[@id="__layout"]/div/div[3]/div[4]/main/div/div/div[1]/div[3]/div/div/a')[0]
#      23     bottom = driver.find_elements(By.XPATH, '//*[@id="__layout"]/div/div[3]/div[4]/main/div/div/div[1]/div[3]/div/div')[0]
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:771, in WebDriver.find_elements(self, by, value)
#     769 # Return empty list if driver returns null
#     770 # See https://github.com/SeleniumHQ/selenium/issues/4555
# --> 771 return self.execute(Command.FIND_ELEMENTS, {"using": by, "value": value})["value"] or []
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# InvalidSessionIdException: Message: invalid session id: session deleted as the browser has closed the connection
# from disconnected: not connected to DevTools
#   (Session info: chrome=135.0.7049.116)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF796BFEFA5+77893]
# 	GetHandleVerifier [0x00007FF796BFF000+77984]
# 	(No symbol) [0x00007FF7969C91BA]
# 	(No symbol) [0x00007FF7969B4F15]
# 	(No symbol) [0x00007FF7969D9F04]
# 	(No symbol) [0x00007FF796A4EACF]
# 	(No symbol) [0x00007FF796A6E972]
# 	(No symbol) [0x00007FF796A46F03]
# 	(No symbol) [0x00007FF796A10328]
# 	(No symbol) [0x00007FF796A11093]
# 	GetHandleVerifier [0x00007FF796EB7B6D+2931725]
# 	GetHandleVerifier [0x00007FF796EB2132+2908626]
# 	GetHandleVerifier [0x00007FF796ED00F3+3031443]
# 	GetHandleVerifier [0x00007FF796C191EA+184970]
# 	GetHandleVerifier [0x00007FF796C2086F+215311]
# 	GetHandleVerifier [0x00007FF796C06EC4+110436]
# 	GetHandleVerifier [0x00007FF796C07072+110866]
# 	GetHandleVerifier [0x00007FF796BED479+5401]
# 	BaseThreadInitThunk [0x00007FFBBD2B259D+29]
# 	RtlUserThreadStart [0x00007FFBBDA8AF38+40]
#
#
# During handling of the above exception, another exception occurred:
#
# InvalidSessionIdException                 Traceback (most recent call last)
# Cell In[2], line 27
#      25     action.move_to_element(bottom).perform()
#      26 except:
# ---> 27     bottom = driver.find_elements(By.CLASS_NAME, "post-card-inline__title")[-1]
#      28     action = ActionChains(driver)
#      29     action.move_to_element(bottom).perform()
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:771, in WebDriver.find_elements(self, by, value)
#     767     value = f'[name="{value}"]'
#     769 # Return empty list if driver returns null
#     770 # See https://github.com/SeleniumHQ/selenium/issues/4555
# --> 771 return self.execute(Command.FIND_ELEMENTS, {"using": by, "value": value})["value"] or []
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#     349     return response
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# InvalidSessionIdException: Message: invalid session id
# Stacktrace:
# 	GetHandleVerifier [0x00007FF796BFEFA5+77893]
# 	GetHandleVerifier [0x00007FF796BFF000+77984]
# 	(No symbol) [0x00007FF7969C8FEC]
# 	(No symbol) [0x00007FF796A0F44F]
# 	(No symbol) [0x00007FF796A46FF2]
# 	(No symbol) [0x00007FF796A41A02]
# 	(No symbol) [0x00007FF796A40AC9]
# 	(No symbol) [0x00007FF796995AB5]
# 	GetHandleVerifier [0x00007FF796EB7B6D+2931725]
# 	GetHandleVerifier [0x00007FF796EB2132+2908626]
# 	GetHandleVerifier [0x00007FF796ED00F3+3031443]
# 	GetHandleVerifier [0x00007FF796C191EA+184970]
# 	GetHandleVerifier [0x00007FF796C2086F+215311]
# 	(No symbol) [0x00007FF796994B2C]
# 	GetHandleVerifier [0x00007FF796FC2518+4023736]
# 	BaseThreadInitThunk [0x00007FFBBD2B259D+29]
# 	RtlUserThreadStart [0x00007FFBBDA8AF38+40]

# %%
/html/head/script[14]/text()

# %%
len(content)
# Out:
# 5009

# %%
links = soup.find_all("a",attrs={"class":"post-card-inline__figure-link"})
links[0].get('href')
# Out:
# '/news/yuga-labs-sells-crypto-punks-ip-infinite-node-foundation'

# %%
content[0].text.strip()
# Out:
# 'Yuga Labs sells CryptoPunks IP to Infinite Node Foundation  May 13, 2025 by\xa0Alex O’Donnell'

# %%
import pandas as pd
import numpy as np

# %%
data = []
links = soup.find_all("a",attrs={"class":"post-card-inline__figure-link"})
data.extend([(v.text.strip(), datetime.now(), 'https://www.cointelegraph.com' + links[i].get('href')) for i, v in enumerate(content)])

# %%
df = pd.DataFrame(data, columns = ['header', 'date', 'link'])
df.head()
# Out:
#                                               header  \
# 0  Yuga Labs sells CryptoPunks IP to Infinite Nod...
# 1  Brave adds Cardano blockchain support to brows...
# 2  DeGods NFT founder steps down as collection ga...
# 3  Teens kidnap Las Vegas man at gunpoint, steali...
# 4  Doodles NFT token stalls after airdrop  May 09...
#
#                         date  \
# 0 2025-05-14 20:03:29.853764
# 1 2025-05-14 20:03:29.853764
# 2 2025-05-14 20:03:29.853764
# 3 2025-05-14 20:03:29.853764
# 4 2025-05-14 20:03:29.853764
#
#                                                 link
# 0  https://www.cointelegraph.com/news/yuga-labs-s...
# 1  https://www.cointelegraph.com/news/brave-brows...
# 2  https://www.cointelegraph.com/news/degods-fran...
# 3  https://www.cointelegraph.com/news/florida-tee...
# 4  https://www.cointelegraph.com/news/doodles-nft...

# %%
df.tail(1).link.values
# Out:
# array(['https://www.cointelegraph.com/news/with-the-rise-of-nfts-pay-to-win-games-have-got-mightily-expensive'],
#       dtype=object)

# %%
df.to_csv('./cointelegraph_nft_2025-2020-10.csv', index = False)
